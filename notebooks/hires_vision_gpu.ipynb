# %% [markdown]
# # Hi-res 1601² CFDAC — vision backbones: ConvNeXt-T & ResNet50 (GPU)
#
# Two ImageNet-pretrained **CNN** backbones (the transformer paradigm is covered by the separate transformer notebook): **ConvNeXt-T** (strongest modern CNN) and **ResNet50** (the classic baseline — the exact backbone the paper used for vision transfer, so results are directly comparable). Both fully-convolutional, fed at `VISION_SIZE`=384 (>> the 224 baseline). CFDAC × 7 features × 10 tasks = 2×7×10 = 140 cells. (All 5 backbones remain in `Z.VISION_BACKBONES` if you widen `MODELS`.)
#
# **No GPU? Set Runtime → Change runtime type → GPU.** Private repos: add a Colab secret `GH_TOKEN`. Results persist to Google Drive; **File → Save a copy in GitHub** saves this notebook itself. Set `CELLS` to one tuple to run a single cell per session.

# %% [markdown]
# ## 1 · Bootstrap (clone phd_lanl + pymodal, install deps incl. pint/pyFRF/audiomentations)

# %%
import os, sys, subprocess
GH_USER='grcarmenaty'; WORK='/content'; os.chdir(WORK)
def _tok():
    try:
        from google.colab import userdata; return userdata.get('GH_TOKEN')
    except Exception: return os.environ.get('GH_TOKEN')
def clone(repo, branch, dst):
    if os.path.isdir(dst): print('exists', dst); return
    t=_tok(); auth=f'{t}@' if t else ''
    url=f'https://{auth}github.com/{GH_USER}/{repo}.git'
    assert subprocess.run(['git','clone','--depth','1','-b',branch,url,dst]).returncode==0, \
        f'clone failed {repo}@{branch} (private? add a GH_TOKEN Colab secret)'
clone('phd_lanl','main','/content/PhD_LANL')
clone('pymodal','master','/content/pymodal')   # sibling dir the scripts expect
for p in ('/content/PhD_LANL','/content/pymodal'):
    if p not in sys.path: sys.path.insert(0,p)
os.chdir('/content/PhD_LANL')
# Harden git's HTTP transport against Drive-mounted-Colab flakiness (the 408s):
for _k,_v in [('http.postBuffer','524288000'),('http.version','HTTP/1.1'),
              ('http.lowSpeedLimit','1000'),('http.lowSpeedTime','300')]:
    subprocess.run(['git','config','--global',_k,_v])
subprocess.run([sys.executable,'-m','pip','-q','install','timm','h5py','scikit-learn','pint','pyFRF','audiomentations'])
import torch
print('torch',torch.__version__,'| cuda',torch.cuda.is_available(),'|',
      torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU - set a GPU runtime!')
# Out:
# exists /content/PhD_LANL
# exists /content/pymodal
# torch 2.11.0+cu128 | cuda True | NVIDIA L4

# %% [markdown]
# ## 2 · Regenerate the 1601-bin features (gitignored; rebuilt from committed sources)

# %%
import subprocess, sys, os, glob, json, h5py, numpy as np
from pathlib import Path
REPO=Path(os.getcwd())
def run(cmd): print('>>',' '.join(cmd)); assert subprocess.run(cmd).returncode==0, cmd
if not (REPO/'dataset'/'features_hires.h5').exists():
    run([sys.executable,'ml_pipeline/generate_dataset.py','--out','dataset_hires','--n-t','4096','--fs','256'])
    run([sys.executable,'ml_pipeline/build_hires_synth_features.py'])
if not (REPO/'experimental_frfs.h5').exists():
    with open('experimental_frfs.h5','wb') as o:
        for p in sorted(glob.glob('experimental_frfs_chunks/experimental_frfs.h5.part_*')):
            o.write(open(p,'rb').read())
if not (REPO/'dataset'/'experimental_features.h5').exists():
    from ml_pipeline.evaluate import primary_op
    with h5py.File('experimental_frfs.h5','r') as f: names=json.loads(f.attrs['case_names_json'])
    n=len(names); tc=np.zeros(n,np.int8); st=np.full(n,-1,np.int8); en=np.full(n,-1,np.int8); sv=np.zeros(n,np.float32)
    for i,nm in enumerate(names):
        op=primary_op(nm); tc[i]=op['type_code']; st[i]=op['storey']; en[i]=op['end']; sv[i]=op['severity']
    dt=h5py.string_dtype('utf-8')
    with h5py.File('dataset/experimental_features.h5','w') as o:
        o.create_dataset('names',data=np.array(names,dtype=object),dtype=dt)
        o.create_dataset('type_code',data=tc); o.create_dataset('storey',data=st)
        o.create_dataset('end',data=en); o.create_dataset('severity',data=sv)
if not (REPO/'dataset'/'experimental_features_hires.h5').exists():
    run([sys.executable,'ml_pipeline/build_hires_exp_features.py'])
print('features ready')
# Out:
# features ready

# %% [markdown]
# ## 3 · Config + context (edit the CONFIG block)

# %%
import torch, numpy as np, h5py
from pathlib import Path
from ml_pipeline import hires_zoo as Z
from ml_pipeline.tasks import build_targets
from ml_pipeline.train import make_split
DEV=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ===================== CONFIG (edit me) =====================
MODELS   = ['convnext_tiny','resnet50']
TASKS    = ['binary','col_location','mass_location','severity','type',
            'is_bolt','is_crack','is_mass','is_hole','is_pristine']
FEATURES = list(Z.CFDAC_FEATURES)          # all 7 CFDAC channel-features
MAX_EPOCHS = 80        # safety cap; training stops early at convergence
PATIENCE   = 8         # early-stop after this many epochs with no val gain
SUBSAMPLE= 4000        # A100 fits this easily; raise toward 10000 for more data
BATCH    = 32          # tuned to THIS model's memory footprint; drop on smaller GPUs / if OOM
VISION_SIZE = 384      # conv vision backbones feed size (swin/vit fixed 224); A100 can do 448-512
# --- GitHub autosave (each finished cell -> a per-family results branch) ---
FAMILY            = 'vision'
AUTOSAVE_GITHUB   = True                               # set False to disable
GH_RESULTS_BRANCH = 'colab-hires-vision'         # never touches main
# Full grid below. To run ONE cell this session set e.g.:
#   CELLS = [('type','transformer','cfdac_realimag')]
CELLS = Z.all_cfdac_cells(MODELS, TASKS, FEATURES)
print(len(CELLS),'cells queued across', MODELS)
# ============================================================

# Persistence: Google Drive survives Colab session resets (skip-if-exists resumes).
try:
    from google.colab import drive; drive.mount('/content/drive')
    OUT=Path('/content/drive/MyDrive/hires_cfdac/vision')
except Exception:
    OUT=Path('results_hires_zoo_vision')
OUT.mkdir(parents=True, exist_ok=True); print('OUT =', OUT)

# Pick up cells already trained in a past run: seed OUT/per_case from the
# results branch (so we never retrain past work, even on a fresh session/Drive).
_BR = 'colab-hires-vision'
import subprocess as _sp, os as _os
try:
    _sp.run(['git','-C','/content/PhD_LANL','fetch','--depth','1','origin',_BR], capture_output=True)
    _ls = _sp.run(['git','-C','/content/PhD_LANL','ls-tree','-r','--name-only','FETCH_HEAD'],
                  capture_output=True, text=True).stdout
    (OUT/'per_case').mkdir(parents=True, exist_ok=True); _n=0
    for _l in _ls.splitlines():
        if 'results_hires_zoo/vision/per_case/' in _l and _l.endswith('.json'):
            _name=_os.path.basename(_l)
            if not (OUT/'per_case'/_name).exists():
                _b=_sp.run(['git','-C','/content/PhD_LANL','show','FETCH_HEAD:'+_l],
                           capture_output=True, text=True).stdout
                if _b: (OUT/'per_case'/_name).write_text(_b); _n+=1
    print('picked up',_n,'already-trained cells from',_BR)
except Exception as _e:
    print('branch pickup skipped:', _e)

SYN=Path('dataset/features_hires.h5'); EXP=Path('dataset/experimental_features_hires.h5')
with h5py.File(SYN,'r') as f:
    syn_tasks=build_targets(f['type_code'][:].astype('int64'),f['storey'][:].astype('int64'),
                            f['end'][:].astype('int64'),f['severity'][:].astype('float32'))
    H_ref_syn=torch.from_numpy(f['reference/frf_complex'][:].astype('complex64')).to(DEV)
with h5py.File(EXP,'r') as f:
    exp_tasks=build_targets(f['type_code'][:].astype('int64'),f['storey'][:].astype('int64'),
                            f['end'][:].astype('int64'),f['severity'][:].astype('float32'))
    exp_names=[str(s) for s in f['names'][:]]
    H_ref_exp=torch.from_numpy(f['reference/frf_complex'][:].astype('complex64')).to(DEV)
with h5py.File(EXP,'r') as f:
    H_exp=(f['frf_real'][:]+1j*f['frf_imag'][:]).astype('complex64')
print('context ready; exp FRFs', H_exp.shape)
print('device', DEV, '| amp dtype', Z._amp_dtype(DEV),
      '| (bfloat16 expected on A100/H100)')
# Out:
# 140 cells queued across ['convnext_tiny', 'resnet50']
# Mounted at /content/drive
# OUT = /content/drive/MyDrive/hires_cfdac/vision
# picked up 79 already-trained cells from colab-hires-vision
# context ready; exp FRFs (2638, 1601, 9)
# device cuda | amp dtype torch.bfloat16 | (bfloat16 expected on A100/H100)

# %% [markdown]
# ## 4 · Run the cell grid (skip-if-exists; resumes from Drive)

# %%
import torch, os, shutil, subprocess
def _tok():
    try:
        from google.colab import userdata; return userdata.get('GH_TOKEN')
    except Exception: return os.environ.get('GH_TOKEN')
GH_TOKEN = _tok()
if AUTOSAVE_GITHUB and not GH_TOKEN:
    print('AUTOSAVE_GITHUB is on but no GH_TOKEN secret found -> results go to Drive/zip only.')

def git_autosave(msg):
    """Force-push the JSON results of THIS family to its own results branch.
    Only per_case/*.json + synth_test_zoo.json are pushed (NOT the model
    .ckpt/.pt weights, which stay on Drive). Per-family branch => never
    conflicts with main or other families; always the full accumulated state."""
    if not (AUTOSAVE_GITHUB and GH_TOKEN): return
    repo='/content/PhD_LANL'; dst=os.path.join(repo,'results_hires_zoo',FAMILY)
    os.makedirs(os.path.join(dst,'per_case'), exist_ok=True)
    if not getattr(git_autosave,'_merged',False):   # one-time: pull remote cells so a force-push never overwrites a fuller branch
        subprocess.run(['git','-C',repo,'fetch','--depth','1','origin',GH_RESULTS_BRANCH],capture_output=True)
        _rl=subprocess.run(['git','-C',repo,'ls-tree','-r','--name-only','FETCH_HEAD'],capture_output=True,text=True).stdout
        for _l in _rl.splitlines():
            if '/per_case/' in _l and _l.endswith('.json'):
                _fp=os.path.join(str(OUT),'per_case',os.path.basename(_l))
                if not os.path.exists(_fp):
                    _bb=subprocess.run(['git','-C',repo,'show','FETCH_HEAD:'+_l],capture_output=True,text=True).stdout
                    if _bb: open(_fp,'w').write(_bb)
        git_autosave._merged=True
    # copy ONLY the json artefacts (skip the large models/ dir)
    for fn in os.listdir(os.path.join(OUT,'per_case')) if os.path.isdir(os.path.join(OUT,'per_case')) else []:
        if fn.endswith('.json'): shutil.copy(os.path.join(OUT,'per_case',fn), os.path.join(dst,'per_case',fn))
    if os.path.exists(os.path.join(OUT,'synth_test_zoo.json')):
        shutil.copy(os.path.join(OUT,'synth_test_zoo.json'), os.path.join(dst,'synth_test_zoo.json'))
    cwd=os.getcwd(); os.chdir(repo)
    subprocess.run(['git','config','user.email','colab@gpu.run'])
    subprocess.run(['git','config','user.name','colab-gpu'])
    subprocess.run(['git','add','-f',f'results_hires_zoo/{FAMILY}/per_case',f'results_hires_zoo/{FAMILY}/synth_test_zoo.json'])
    if subprocess.run(['git','diff','--cached','--quiet']).returncode!=0:
        subprocess.run(['git','commit','-q','-m',msg])
        url=f'https://{GH_TOKEN}@github.com/grcarmenaty/phd_lanl.git'
        import time as _t; ok=False
        for _a in range(5):                       # retry the flaky push w/ backoff
            r=subprocess.run(['git','push','--force',url,f'HEAD:{GH_RESULTS_BRANCH}'],
                             capture_output=True,text=True)
            if r.returncode==0: ok=True; break
            _t.sleep(4*(2**_a))                    # 4,8,16,32,64s
        print('  autosave:', f'pushed -> {GH_RESULTS_BRANCH}' if ok
              else 'push failed after retries (results safe on Drive): '+r.stderr[-140:])
    os.chdir(cwd)

for (task, model, feature) in CELLS:
    try:
        Z.run_cell(task, model, feature, syn_h5=SYN, exp_h5=EXP, out_dir=OUT, dev=DEV,
                   syn_tasks=syn_tasks, exp_tasks=exp_tasks, H_ref_syn=H_ref_syn,
                   H_ref_exp=H_ref_exp, H_exp=H_exp, exp_names=exp_names,
                   make_split=make_split, subsample=SUBSAMPLE, batch=BATCH,
                   vision_size=VISION_SIZE, max_epochs=MAX_EPOCHS, patience=PATIENCE)
        git_autosave(f'colab autosave [{FAMILY}]: {task}/{model}/{feature}')
    except Exception as e:
        print('CELL FAILED', task, model, feature, '::', repr(e)[:200])
        if torch.cuda.is_available(): torch.cuda.empty_cache()
print('\nqueue done')
# Out:
# skip binary_convnext_tiny_cfdac_real_hires1601 (exists)
#   autosave: pushed -> colab-hires-vision
# skip binary_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip binary_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip binary_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip binary_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip binary_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip binary_convnext_tiny_cfdac_all_hires1601 (exists)
# skip binary_resnet50_cfdac_real_hires1601 (exists)
# skip binary_resnet50_cfdac_imag_hires1601 (exists)
# skip binary_resnet50_cfdac_mag_hires1601 (exists)
# skip binary_resnet50_cfdac_phase_hires1601 (exists)
# skip binary_resnet50_cfdac_realimag_hires1601 (exists)
# skip binary_resnet50_cfdac_magphase_hires1601 (exists)
# skip binary_resnet50_cfdac_all_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_real_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip col_location_convnext_tiny_cfdac_all_hires1601 (exists)
# skip col_location_resnet50_cfdac_real_hires1601 (exists)
# skip col_location_resnet50_cfdac_imag_hires1601 (exists)
# skip col_location_resnet50_cfdac_mag_hires1601 (exists)
# skip col_location_resnet50_cfdac_phase_hires1601 (exists)
# skip col_location_resnet50_cfdac_realimag_hires1601 (exists)
# skip col_location_resnet50_cfdac_magphase_hires1601 (exists)
# skip col_location_resnet50_cfdac_all_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_real_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip mass_location_convnext_tiny_cfdac_all_hires1601 (exists)
# skip mass_location_resnet50_cfdac_real_hires1601 (exists)
# skip mass_location_resnet50_cfdac_imag_hires1601 (exists)
# skip mass_location_resnet50_cfdac_mag_hires1601 (exists)
# skip mass_location_resnet50_cfdac_phase_hires1601 (exists)
# skip mass_location_resnet50_cfdac_realimag_hires1601 (exists)
# skip mass_location_resnet50_cfdac_magphase_hires1601 (exists)
# skip mass_location_resnet50_cfdac_all_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_real_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip severity_convnext_tiny_cfdac_all_hires1601 (exists)
# skip severity_resnet50_cfdac_real_hires1601 (exists)
# skip severity_resnet50_cfdac_imag_hires1601 (exists)
# skip severity_resnet50_cfdac_mag_hires1601 (exists)
# skip severity_resnet50_cfdac_phase_hires1601 (exists)
# skip severity_resnet50_cfdac_realimag_hires1601 (exists)
# skip severity_resnet50_cfdac_magphase_hires1601 (exists)
# skip severity_resnet50_cfdac_all_hires1601 (exists)
# skip type_convnext_tiny_cfdac_real_hires1601 (exists)
# skip type_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip type_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip type_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip type_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip type_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip type_convnext_tiny_cfdac_all_hires1601 (exists)
# skip type_resnet50_cfdac_real_hires1601 (exists)
# skip type_resnet50_cfdac_imag_hires1601 (exists)
# skip type_resnet50_cfdac_mag_hires1601 (exists)
# skip type_resnet50_cfdac_phase_hires1601 (exists)
# skip type_resnet50_cfdac_realimag_hires1601 (exists)
# skip type_resnet50_cfdac_magphase_hires1601 (exists)
# skip type_resnet50_cfdac_all_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_real_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip is_bolt_convnext_tiny_cfdac_all_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_real_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_imag_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_mag_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_phase_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_realimag_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_magphase_hires1601 (exists)
# skip is_bolt_resnet50_cfdac_all_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_real_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip is_crack_convnext_tiny_cfdac_all_hires1601 (exists)
# skip is_crack_resnet50_cfdac_real_hires1601 (exists)
# skip is_crack_resnet50_cfdac_imag_hires1601 (exists)
# skip is_crack_resnet50_cfdac_mag_hires1601 (exists)
# skip is_crack_resnet50_cfdac_phase_hires1601 (exists)
# skip is_crack_resnet50_cfdac_realimag_hires1601 (exists)
# skip is_crack_resnet50_cfdac_magphase_hires1601 (exists)
# skip is_crack_resnet50_cfdac_all_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_real_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip is_mass_convnext_tiny_cfdac_all_hires1601 (exists)
# skip is_mass_resnet50_cfdac_real_hires1601 (exists)
# skip is_mass_resnet50_cfdac_imag_hires1601 (exists)
# skip is_mass_resnet50_cfdac_mag_hires1601 (exists)
# skip is_mass_resnet50_cfdac_phase_hires1601 (exists)
# skip is_mass_resnet50_cfdac_realimag_hires1601 (exists)
# skip is_mass_resnet50_cfdac_magphase_hires1601 (exists)
# skip is_mass_resnet50_cfdac_all_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_real_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip is_hole_convnext_tiny_cfdac_all_hires1601 (exists)
# skip is_hole_resnet50_cfdac_real_hires1601 (exists)
# skip is_hole_resnet50_cfdac_imag_hires1601 (exists)
# skip is_hole_resnet50_cfdac_mag_hires1601 (exists)
# skip is_hole_resnet50_cfdac_phase_hires1601 (exists)
# skip is_hole_resnet50_cfdac_realimag_hires1601 (exists)
# skip is_hole_resnet50_cfdac_magphase_hires1601 (exists)
# skip is_hole_resnet50_cfdac_all_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_real_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_imag_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_mag_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_phase_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_realimag_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_magphase_hires1601 (exists)
# skip is_pristine_convnext_tiny_cfdac_all_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_real_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_imag_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_mag_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_phase_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_realimag_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_magphase_hires1601 (exists)
# skip is_pristine_resnet50_cfdac_all_hires1601 (exists)
#
# queue done

# %% [markdown]
# ## 5 · Honest summary (balanced-acc / macro-F1 / collapse) + zip download

# %%
import json, numpy as np
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score, f1_score, accuracy_score
print(f"{'cell':<48}{'kind':>5}{'synth':>8}{'expMF1/R2':>11}{'expBal':>8}{'expAcc':>8}{'collapse':>9}")
print('-'*97)
for p in sorted((OUT/'per_case').glob('*_hires1601.json')):
    d=json.loads(p.read_text()); m=d['meta']; r=d['rows']
    yt=np.array([x['y_true'] for x in r]); yp=np.array([x['y_pred'] for x in r])
    name=f"{m['task']}/{m['model']}/{m['feature']}"
    if m['kind']=='cls':
        n=m['n_out']; bal=balanced_accuracy_score(yt,yp)
        mf1=f1_score(yt,yp,labels=list(range(n)),average='macro',zero_division=0); acc=accuracy_score(yt,yp)
        coll=(len(set(yp.tolist()))<=1) or (bal<=1/n+0.02)
        print(f"{name:<48}{'cls':>5}{(m.get('synth_test_macro_f1') or 0):>8.3f}{mf1:>11.3f}{bal:>8.3f}{acc:>8.3f}{str(coll):>9}")
    else:
        yt=yt.astype(float); yp=yp.astype(float); ss=np.sum((yt-yp)**2); st=np.sum((yt-yt.mean())**2)
        r2=1-ss/st if st>0 else 0; mae=np.mean(np.abs(yt-yp))
        print(f"{name:<48}{'reg':>5}{(m.get('synth_test_metric') or 0):>8.3f}{r2:>11.3f}{'-':>8}{'-':>8}{'MAE=%.3f'%mae:>9}")

# Zip for download (Drive already persists across sessions).
import shutil
z=str(OUT).rstrip('/').split('/')[-1]
shutil.make_archive('/content/'+z,'zip',str(OUT))
try:
    from google.colab import files; files.download('/content/'+z+'.zip')
except Exception as e: print('zip at /content/'+z+'.zip', e)
# Out:
# cell                                             kind   synth  expMF1/R2  expBal  expAcc collapse
# -------------------------------------------------------------------------------------------------
# binary/cnn2d/cfdac_realimag                       cls   0.447      0.452   0.500   0.825     True
# binary/cnn2d_deep/cfdac_imag                      cls   0.773      0.439   0.452   0.726     True
# binary/cnn2d_deep/cfdac_mag                       cls   0.688      0.491   0.514   0.818     True
# binary/cnn2d_deep/cfdac_phase                     cls   0.796      0.438   0.468   0.770     True
# binary/cnn2d_deep/cfdac_real                      cls   0.729      0.427   0.422   0.641     True
# binary/convnext_tiny/cfdac_all                    cls   0.948      0.453   0.498   0.821     True
# binary/convnext_tiny/cfdac_imag                   cls   0.962      0.480   0.513   0.828     True
# binary/convnext_tiny/cfdac_mag                    cls   0.444      0.452   0.500   0.825     True
# binary/convnext_tiny/cfdac_magphase               cls   0.944      0.463   0.502   0.820     True
# binary/convnext_tiny/cfdac_phase                  cls   0.951      0.452   0.500   0.825     True
# binary/convnext_tiny/cfdac_real                   cls   0.936      0.507   0.513   0.782     True
# binary/convnext_tiny/cfdac_realimag               cls   0.954      0.491   0.511   0.810     True
# binary/resnet50/cfdac_all                         cls   0.933      0.452   0.500   0.825     True
# binary/resnet50/cfdac_imag                        cls   0.881      0.463   0.496   0.805     True
# binary/resnet50/cfdac_mag                         cls   0.795      0.452   0.500   0.825     True
# binary/resnet50/cfdac_magphase                    cls   0.921      0.452   0.500   0.825     True
# binary/resnet50/cfdac_phase                       cls   0.945      0.525   0.527   0.791    False
# binary/resnet50/cfdac_real                        cls   0.886      0.453   0.496   0.815     True
# binary/resnet50/cfdac_realimag                    cls   0.900      0.452   0.500   0.825     True
# col_location/cnn2d/cfdac_realimag                 cls   0.070      0.114   0.237   0.221    False
# col_location/convnext_tiny/cfdac_all              cls   0.048      0.019   0.167   0.062     True
# col_location/convnext_tiny/cfdac_imag             cls   0.048      0.019   0.167   0.062     True
# col_location/convnext_tiny/cfdac_mag              cls   0.048      0.019   0.167   0.062     True
# col_location/convnext_tiny/cfdac_magphase         cls   0.471      0.127   0.324   0.173    False
# col_location/convnext_tiny/cfdac_phase            cls   0.488      0.070   0.125   0.148     True
# col_location/convnext_tiny/cfdac_real             cls   0.447      0.039   0.185   0.055     True
# col_location/convnext_tiny/cfdac_realimag         cls   0.464      0.128   0.163   0.250     True
# col_location/resnet50/cfdac_all                   cls   0.486      0.066   0.123   0.179     True
# col_location/resnet50/cfdac_imag                  cls   0.464      0.147   0.160   0.330     True
# col_location/resnet50/cfdac_mag                   cls   0.483      0.125   0.199   0.367    False
# col_location/resnet50/cfdac_magphase              cls   0.465      0.132   0.185   0.327     True
# col_location/resnet50/cfdac_phase                 cls   0.514      0.099   0.164   0.132     True
# col_location/resnet50/cfdac_real                  cls   0.471      0.089   0.165   0.352     True
# col_location/resnet50/cfdac_realimag              cls   0.494      0.087   0.164   0.349     True
# is_bolt/convnext_tiny/cfdac_all                   cls   0.914      0.612   0.612   0.612    False
# is_bolt/convnext_tiny/cfdac_imag                  cls   0.925      0.633   0.640   0.638    False
# is_bolt/convnext_tiny/cfdac_mag                   cls   0.444      0.330   0.500   0.493     True
# is_bolt/convnext_tiny/cfdac_magphase              cls   0.917      0.559   0.565   0.566    False
# is_bolt/convnext_tiny/cfdac_phase                 cls   0.917      0.609   0.614   0.612    False
# is_bolt/convnext_tiny/cfdac_real                  cls   0.917      0.541   0.541   0.542    False
# is_bolt/convnext_tiny/cfdac_realimag              cls   0.929      0.592   0.619   0.615    False
# is_bolt/resnet50/cfdac_all                        cls   0.917      0.337   0.500   0.507     True
# is_bolt/resnet50/cfdac_imag                       cls   0.925      0.337   0.500   0.507     True
# is_bolt/resnet50/cfdac_mag                        cls   0.916      0.543   0.548   0.550    False
# is_bolt/resnet50/cfdac_magphase                   cls   0.935      0.337   0.500   0.507     True
# is_bolt/resnet50/cfdac_phase                      cls   0.933      0.337   0.500   0.507     True
# is_bolt/resnet50/cfdac_real                       cls   0.913      0.350   0.505   0.512     True
# is_bolt/resnet50/cfdac_realimag                   cls   0.925      0.337   0.500   0.507     True
# is_crack/convnext_tiny/cfdac_all                  cls   0.444      0.468   0.500   0.879     True
# is_crack/convnext_tiny/cfdac_imag                 cls   0.444      0.468   0.500   0.879     True
# is_crack/convnext_tiny/cfdac_mag                  cls   0.444      0.468   0.500   0.879     True
# is_crack/convnext_tiny/cfdac_magphase             cls   0.444      0.468   0.500   0.879     True
# is_crack/convnext_tiny/cfdac_phase                cls   0.766      0.577   0.579   0.816    False
# is_crack/convnext_tiny/cfdac_real                 cls   0.444      0.468   0.500   0.879     True
# is_crack/convnext_tiny/cfdac_realimag             cls   0.766      0.546   0.542   0.834    False
# is_crack/resnet50/cfdac_all                       cls   0.731      0.468   0.500   0.879     True
# is_crack/resnet50/cfdac_imag                      cls   0.720      0.471   0.502   0.879     True
# is_crack/resnet50/cfdac_mag                       cls   0.708      0.447   0.461   0.810     True
# is_crack/resnet50/cfdac_magphase                  cls   0.720      0.468   0.500   0.879     True
# is_crack/resnet50/cfdac_phase                     cls   0.756      0.468   0.500   0.879     True
# is_crack/resnet50/cfdac_real                      cls   0.745      0.468   0.500   0.879     True
# is_crack/resnet50/cfdac_realimag                  cls   0.764      0.468   0.500   0.879     True
# is_hole/convnext_tiny/cfdac_all                   cls   0.444      0.472   0.500   0.894     True
# is_hole/convnext_tiny/cfdac_imag                  cls   0.444      0.472   0.500   0.894     True
# is_hole/convnext_tiny/cfdac_mag                   cls   0.444      0.472   0.500   0.894     True
# is_hole/convnext_tiny/cfdac_magphase              cls   0.653      0.536   0.532   0.883    False
# is_hole/convnext_tiny/cfdac_phase                 cls   0.444      0.472   0.500   0.894     True
# is_hole/convnext_tiny/cfdac_real                  cls   0.444      0.472   0.500   0.894     True
# is_hole/convnext_tiny/cfdac_realimag              cls   0.444      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_all                        cls   0.706      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_imag                       cls   0.758      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_mag                        cls   0.614      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_magphase                   cls   0.711      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_phase                      cls   0.756      0.497   0.502   0.855     True
# is_hole/resnet50/cfdac_real                       cls   0.718      0.472   0.500   0.894     True
# is_hole/resnet50/cfdac_realimag                   cls   0.608      0.472   0.500   0.894     True
# is_mass/convnext_tiny/cfdac_all                   cls   0.968      0.507   0.605   0.671    False
# is_mass/convnext_tiny/cfdac_imag                  cls   0.445      0.476   0.500   0.910     True
# is_mass/convnext_tiny/cfdac_mag                   cls   0.445      0.476   0.500   0.910     True
# is_mass/convnext_tiny/cfdac_magphase              cls   0.973      0.430   0.493   0.574     True
# is_mass/convnext_tiny/cfdac_phase                 cls   0.445      0.476   0.500   0.910     True
# is_mass/convnext_tiny/cfdac_real                  cls   0.952      0.381   0.545   0.448    False
# is_mass/convnext_tiny/cfdac_realimag              cls   0.941      0.514   0.604   0.687    False
# is_mass/resnet50/cfdac_all                        cls   0.953      0.083   0.500   0.090     True
# is_mass/resnet50/cfdac_imag                       cls   0.968      0.418   0.397   0.674     True
# is_mass/resnet50/cfdac_mag                        cls   0.889      0.201   0.535   0.202    False
# is_mass/resnet50/cfdac_magphase                   cls   0.948      0.083   0.500   0.090     True
# is_mass/resnet50/cfdac_phase                      cls   0.964      0.156   0.446   0.157     True
# is_mass/resnet50/cfdac_real                       cls   0.967      0.086   0.502   0.093     True
# is_mass/resnet50/cfdac_realimag                   cls   0.973      0.083   0.500   0.090     True
# is_pristine/convnext_tiny/cfdac_all               cls   0.444      0.452   0.500   0.825     True
# is_pristine/convnext_tiny/cfdac_imag              cls   0.957      0.452   0.500   0.825     True
# is_pristine/convnext_tiny/cfdac_mag               cls   0.444      0.452   0.500   0.825     True
# is_pristine/convnext_tiny/cfdac_magphase          cls   0.957      0.452   0.500   0.825     True
# is_pristine/convnext_tiny/cfdac_phase             cls   0.917      0.561   0.556   0.834    False
# is_pristine/convnext_tiny/cfdac_real              cls   0.952      0.452   0.495   0.813     True
# is_pristine/convnext_tiny/cfdac_realimag          cls   0.964      0.502   0.524   0.831    False
# is_pristine/resnet50/cfdac_all                    cls   0.947      0.452   0.500   0.825     True
# is_pristine/resnet50/cfdac_imag                   cls   0.913      0.465   0.473   0.734     True
# is_pristine/resnet50/cfdac_mag                    cls   0.805      0.452   0.500   0.825     True
# is_pristine/resnet50/cfdac_magphase               cls   0.902      0.452   0.500   0.825     True
# is_pristine/resnet50/cfdac_phase                  cls   0.954      0.452   0.499   0.823     True
# is_pristine/resnet50/cfdac_real                   cls   0.902      0.450   0.496   0.818     True
# is_pristine/resnet50/cfdac_realimag               cls   0.791      0.454   0.501   0.825     True
# mass_location/cnn2d/cfdac_realimag                cls   0.362      0.130   0.197   0.315     True
# mass_location/convnext_tiny/cfdac_all             cls   0.980      0.362   0.405   0.403    False
# mass_location/convnext_tiny/cfdac_imag            cls   0.997      0.228   0.325   0.378    False
# mass_location/convnext_tiny/cfdac_mag             cls   0.100      0.145   0.250   0.408     True
# mass_location/convnext_tiny/cfdac_magphase        cls   0.983      0.103   0.250   0.256     True
# mass_location/convnext_tiny/cfdac_phase           cls   0.997      0.080   0.086   0.088     True
# mass_location/convnext_tiny/cfdac_real            cls   0.987      0.060   0.086   0.088     True
# mass_location/convnext_tiny/cfdac_realimag        cls   0.990      0.232   0.287   0.361    False
# mass_location/resnet50/cfdac_all                  cls   0.987      0.072   0.250   0.168     True
# mass_location/resnet50/cfdac_imag                 cls   0.990      0.080   0.250   0.168     True
# mass_location/resnet50/cfdac_mag                  cls   0.964      0.102   0.250   0.256     True
# mass_location/resnet50/cfdac_magphase             cls   0.990      0.072   0.250   0.168     True
# mass_location/resnet50/cfdac_phase                cls   0.987      0.115   0.107   0.139     True
# mass_location/resnet50/cfdac_real                 cls   0.990      0.033   0.085   0.059     True
# mass_location/resnet50/cfdac_realimag             cls   0.983      0.100   0.242   0.248     True
# severity/cnn2d/cfdac_realimag                     reg   0.000     -0.941       -       -MAE=0.362
# severity/convnext_tiny/cfdac_all                  reg   0.586     -0.158       -       -MAE=0.272
# severity/convnext_tiny/cfdac_imag                 reg   0.572     -0.128       -       -MAE=0.263
# severity/convnext_tiny/cfdac_mag                  reg  -0.000     -0.033       -       -MAE=0.268
# severity/convnext_tiny/cfdac_magphase             reg   0.494     -0.422       -       -MAE=0.310
# severity/convnext_tiny/cfdac_phase                reg   0.556     -0.137       -       -MAE=0.281
# severity/convnext_tiny/cfdac_real                 reg   0.549     -0.055       -       -MAE=0.259
# severity/convnext_tiny/cfdac_realimag             reg   0.566     -0.154       -       -MAE=0.271
# severity/resnet50/cfdac_all                       reg   0.435     -0.937       -       -MAE=0.368
# severity/resnet50/cfdac_imag                      reg   0.435     -6.942       -       -MAE=0.815
# severity/resnet50/cfdac_mag                       reg   0.288     -8.224       -       -MAE=0.854
# severity/resnet50/cfdac_magphase                  reg   0.413     -1.038       -       -MAE=0.365
# severity/resnet50/cfdac_phase                     reg   0.413     -0.419       -       -MAE=0.306
# severity/resnet50/cfdac_real                      reg   0.426     -4.941       -       -MAE=0.683
# severity/resnet50/cfdac_realimag                  reg   0.427     -1.143       -       -MAE=0.379
# type/cnn2d/cfdac_realimag                         cls   0.173      0.140   0.158   0.313     True
# type/convnext_tiny/cfdac_all                      cls   0.845      0.132   0.172   0.242     True
# type/convnext_tiny/cfdac_imag                     cls   0.823      0.280   0.306   0.381    False
# type/convnext_tiny/cfdac_mag                      cls   0.067      0.038   0.200   0.106     True
# type/convnext_tiny/cfdac_magphase                 cls   0.821      0.162   0.213   0.487     True
# type/convnext_tiny/cfdac_phase                    cls   0.067      0.060   0.200   0.175     True
# type/convnext_tiny/cfdac_real                     cls   0.837      0.186   0.214   0.287     True
# type/convnext_tiny/cfdac_realimag                 cls   0.850      0.246   0.282   0.339    False
# type/resnet50/cfdac_all                           cls   0.826      0.135   0.198   0.500     True
# type/resnet50/cfdac_imag                          cls   0.789      0.148   0.198   0.457     True
# type/resnet50/cfdac_mag                           cls   0.726      0.034   0.200   0.091     True
# type/resnet50/cfdac_magphase                      cls   0.832      0.148   0.205   0.503     True
# type/resnet50/cfdac_phase                         cls   0.804      0.135   0.200   0.507     True
# type/resnet50/cfdac_real                          cls   0.745      0.047   0.188   0.102     True
# type/resnet50/cfdac_realimag                      cls   0.794      0.124   0.160   0.301     True

# %% [markdown]
# ## 6 · (Optional) push JSON results back to the repo

# %%
# Optional: force the full JSON snapshot to the results branch now (JSON only,
# no model weights). Same robust path as the per-cell autosave; safe to re-run.
import os, subprocess, shutil, glob, time as _t
tok=None
try:
    from google.colab import userdata; tok=userdata.get('GH_TOKEN')
except Exception: tok=os.environ.get('GH_TOKEN')
if not tok:
    print('No GH_TOKEN - download the zip from the cell above and hand it to the agent.')
else:
    repo='/content/PhD_LANL'; dst=os.path.join(repo,'results_hires_zoo',FAMILY)
    os.makedirs(os.path.join(dst,'per_case'), exist_ok=True)
    for fn in (os.listdir(os.path.join(OUT,'per_case')) if os.path.isdir(os.path.join(OUT,'per_case')) else []):
        if fn.endswith('.json'): shutil.copy(os.path.join(OUT,'per_case',fn), os.path.join(dst,'per_case',fn))
    for sj in glob.glob(os.path.join(OUT,'synth_test_*.json')):
        shutil.copy(sj, os.path.join(dst, os.path.basename(sj)))
    os.chdir(repo)
    subprocess.run(['git','config','user.email','colab@gpu.run']); subprocess.run(['git','config','user.name','colab-gpu'])
    subprocess.run(['git','add','-f',f'results_hires_zoo/{FAMILY}'])
    subprocess.run(['git','commit','-q','-m',f'hires {FAMILY} (GPU): manual JSON snapshot'])
    url=f'https://{tok}@github.com/grcarmenaty/phd_lanl.git'; ok=False
    for _a in range(5):
        r=subprocess.run(['git','push','--force',url,f'HEAD:{GH_RESULTS_BRANCH}'],capture_output=True,text=True)
        if r.returncode==0: ok=True; break
        _t.sleep(4*(2**_a))
    print(f'pushed -> {GH_RESULTS_BRANCH}' if ok else 'push failed after retries: '+r.stderr[-200:])
# Out:
# pushed -> colab-hires-vision
