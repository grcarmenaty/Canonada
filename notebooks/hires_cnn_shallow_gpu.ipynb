# %% [markdown]
# # Hi-res 1601² CFDAC — SHALLOW 2-D CNN (GPU)
#
# The light **`cnn2d_shallow`** (128-baseline architecture: stride-4 stem + 3 conv/pool, global-pool) on full-1601² CFDAC × 7 features × 10 tasks. Tiny memory footprint — runs with a large batch on a small/cheap GPU. Shares the `cnn` results folder/branch with the 'rest' notebook (skip-if-exists reuses past runs).
#
# **No GPU? Set Runtime → Change runtime type → GPU.** Private repos: add a Colab secret `GH_TOKEN`. Results persist to Google Drive; **File → Save a copy in GitHub** saves this notebook itself. Set `CELLS` to one tuple to run a single cell per session.

# %% [markdown]
# ## 1 · Bootstrap (clone phd_lanl + pymodal, install deps incl. pint/pyFRF/audiomentations)

# %%
import os, sys, subprocess
GH_USER='grcarmenaty'; WORK='/content'; os.chdir(WORK)
def _tok():
    try:
        from google.colab import userdata; return userdata.get('GH_TOKEN')
    except Exception: return os.environ.get('GH_TOKEN')
def clone(repo, branch, dst):
    if os.path.isdir(dst): print('exists', dst); return
    t=_tok(); auth=f'{t}@' if t else ''
    url=f'https://{auth}github.com/{GH_USER}/{repo}.git'
    assert subprocess.run(['git','clone','--depth','1','-b',branch,url,dst]).returncode==0, \
        f'clone failed {repo}@{branch} (private? add a GH_TOKEN Colab secret)'
clone('phd_lanl','main','/content/PhD_LANL')
clone('pymodal','master','/content/pymodal')   # sibling dir the scripts expect
for p in ('/content/PhD_LANL','/content/pymodal'):
    if p not in sys.path: sys.path.insert(0,p)
os.chdir('/content/PhD_LANL')
# Harden git's HTTP transport against Drive-mounted-Colab flakiness (the 408s):
for _k,_v in [('http.postBuffer','524288000'),('http.version','HTTP/1.1'),
              ('http.lowSpeedLimit','1000'),('http.lowSpeedTime','300')]:
    subprocess.run(['git','config','--global',_k,_v])
subprocess.run([sys.executable,'-m','pip','-q','install','timm','h5py','scikit-learn','pint','pyFRF','audiomentations'])
import torch
print('torch',torch.__version__,'| cuda',torch.cuda.is_available(),'|',
      torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO GPU - set a GPU runtime!')
# Out:
# torch 2.11.0+cu128 | cuda True | NVIDIA L4

# %% [markdown]
# ## 2 · Regenerate the 1601-bin features (gitignored; rebuilt from committed sources)

# %%
import subprocess, sys, os, glob, json, h5py, numpy as np
from pathlib import Path
REPO=Path(os.getcwd())
def run(cmd): print('>>',' '.join(cmd)); assert subprocess.run(cmd).returncode==0, cmd
if not (REPO/'dataset'/'features_hires.h5').exists():
    run([sys.executable,'ml_pipeline/generate_dataset.py','--out','dataset_hires','--n-t','4096','--fs','256'])
    run([sys.executable,'ml_pipeline/build_hires_synth_features.py'])
if not (REPO/'experimental_frfs.h5').exists():
    with open('experimental_frfs.h5','wb') as o:
        for p in sorted(glob.glob('experimental_frfs_chunks/experimental_frfs.h5.part_*')):
            o.write(open(p,'rb').read())
if not (REPO/'dataset'/'experimental_features.h5').exists():
    from ml_pipeline.evaluate import primary_op
    with h5py.File('experimental_frfs.h5','r') as f: names=json.loads(f.attrs['case_names_json'])
    n=len(names); tc=np.zeros(n,np.int8); st=np.full(n,-1,np.int8); en=np.full(n,-1,np.int8); sv=np.zeros(n,np.float32)
    for i,nm in enumerate(names):
        op=primary_op(nm); tc[i]=op['type_code']; st[i]=op['storey']; en[i]=op['end']; sv[i]=op['severity']
    dt=h5py.string_dtype('utf-8')
    with h5py.File('dataset/experimental_features.h5','w') as o:
        o.create_dataset('names',data=np.array(names,dtype=object),dtype=dt)
        o.create_dataset('type_code',data=tc); o.create_dataset('storey',data=st)
        o.create_dataset('end',data=en); o.create_dataset('severity',data=sv)
if not (REPO/'dataset'/'experimental_features_hires.h5').exists():
    run([sys.executable,'ml_pipeline/build_hires_exp_features.py'])
print('features ready')
# Out:
# >> /usr/bin/python3 ml_pipeline/generate_dataset.py --out dataset_hires --n-t 4096 --fs 256
# >> /usr/bin/python3 ml_pipeline/build_hires_synth_features.py
# >> /usr/bin/python3 ml_pipeline/build_hires_exp_features.py
# features ready

# %% [markdown]
# ## 3 · Config + context (edit the CONFIG block)

# %%
import torch, numpy as np, h5py
from pathlib import Path
from ml_pipeline import hires_zoo as Z
from ml_pipeline.tasks import build_targets
from ml_pipeline.train import make_split
DEV=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ===================== CONFIG (edit me) =====================
MODELS   = ['cnn2d_shallow']
TASKS    = ['binary','col_location','mass_location','severity','type',
            'is_bolt','is_crack','is_mass','is_hole','is_pristine']
FEATURES = list(Z.CFDAC_FEATURES)          # all 7 CFDAC channel-features
MAX_EPOCHS = 80        # safety cap; training stops early at convergence
PATIENCE   = 8         # early-stop after this many epochs with no val gain
SUBSAMPLE= 4000        # A100 fits this easily; raise toward 10000 for more data
BATCH    = 128          # tuned to THIS model's memory footprint; drop on smaller GPUs / if OOM
VISION_SIZE = 384      # conv vision backbones feed size (swin/vit fixed 224); A100 can do 448-512
# --- GitHub autosave (each finished cell -> a per-family results branch) ---
FAMILY            = 'cnn'
AUTOSAVE_GITHUB   = True                               # set False to disable
GH_RESULTS_BRANCH = 'colab-hires-cnn'         # never touches main
# Full grid below. To run ONE cell this session set e.g.:
#   CELLS = [('type','transformer','cfdac_realimag')]
CELLS = Z.all_cfdac_cells(MODELS, TASKS, FEATURES)
print(len(CELLS),'cells queued across', MODELS)
# ============================================================

# Persistence: Google Drive survives Colab session resets (skip-if-exists resumes).
try:
    from google.colab import drive; drive.mount('/content/drive')
    OUT=Path('/content/drive/MyDrive/hires_cfdac/cnn')
except Exception:
    OUT=Path('results_hires_zoo_cnn')
OUT.mkdir(parents=True, exist_ok=True); print('OUT =', OUT)

# Pick up cells already trained in a past run: seed OUT/per_case from the
# results branch (so we never retrain past work, even on a fresh session/Drive).
_BR = 'colab-hires-cnn'
import subprocess as _sp, os as _os
try:
    _sp.run(['git','-C','/content/PhD_LANL','fetch','--depth','1','origin',_BR], capture_output=True)
    _ls = _sp.run(['git','-C','/content/PhD_LANL','ls-tree','-r','--name-only','origin/'+_BR],
                  capture_output=True, text=True).stdout
    (OUT/'per_case').mkdir(parents=True, exist_ok=True); _n=0
    for _l in _ls.splitlines():
        if 'results_hires_zoo/cnn/per_case/' in _l and _l.endswith('.json'):
            _name=_os.path.basename(_l)
            if not (OUT/'per_case'/_name).exists():
                _b=_sp.run(['git','-C','/content/PhD_LANL','show','origin/'+_BR+':'+_l],
                           capture_output=True, text=True).stdout
                if _b: (OUT/'per_case'/_name).write_text(_b); _n+=1
    print('picked up',_n,'already-trained cells from',_BR)
except Exception as _e:
    print('branch pickup skipped:', _e)

SYN=Path('dataset/features_hires.h5'); EXP=Path('dataset/experimental_features_hires.h5')
with h5py.File(SYN,'r') as f:
    syn_tasks=build_targets(f['type_code'][:].astype('int64'),f['storey'][:].astype('int64'),
                            f['end'][:].astype('int64'),f['severity'][:].astype('float32'))
    H_ref_syn=torch.from_numpy(f['reference/frf_complex'][:].astype('complex64')).to(DEV)
with h5py.File(EXP,'r') as f:
    exp_tasks=build_targets(f['type_code'][:].astype('int64'),f['storey'][:].astype('int64'),
                            f['end'][:].astype('int64'),f['severity'][:].astype('float32'))
    exp_names=[str(s) for s in f['names'][:]]
    H_ref_exp=torch.from_numpy(f['reference/frf_complex'][:].astype('complex64')).to(DEV)
with h5py.File(EXP,'r') as f:
    H_exp=(f['frf_real'][:]+1j*f['frf_imag'][:]).astype('complex64')
print('context ready; exp FRFs', H_exp.shape)
print('device', DEV, '| amp dtype', Z._amp_dtype(DEV),
      '| (bfloat16 expected on A100/H100)')
# Out:
# 70 cells queued across ['cnn2d_shallow']
# Mounted at /content/drive
# OUT = /content/drive/MyDrive/hires_cfdac/cnn
# picked up 0 already-trained cells from colab-hires-cnn
# context ready; exp FRFs (2638, 1601, 9)
# device cuda | amp dtype torch.bfloat16 | (bfloat16 expected on A100/H100)

# %% [markdown]
# ## 4 · Run the cell grid (skip-if-exists; resumes from Drive)

# %%
import torch, os, shutil, subprocess
def _tok():
    try:
        from google.colab import userdata; return userdata.get('GH_TOKEN')
    except Exception: return os.environ.get('GH_TOKEN')
GH_TOKEN = _tok()
if AUTOSAVE_GITHUB and not GH_TOKEN:
    print('AUTOSAVE_GITHUB is on but no GH_TOKEN secret found -> results go to Drive/zip only.')

def git_autosave(msg):
    """Force-push the JSON results of THIS family to its own results branch.
    Only per_case/*.json + synth_test_zoo.json are pushed (NOT the model
    .ckpt/.pt weights, which stay on Drive). Per-family branch => never
    conflicts with main or other families; always the full accumulated state."""
    if not (AUTOSAVE_GITHUB and GH_TOKEN): return
    repo='/content/PhD_LANL'; dst=os.path.join(repo,'results_hires_zoo',FAMILY)
    os.makedirs(os.path.join(dst,'per_case'), exist_ok=True)
    # copy ONLY the json artefacts (skip the large models/ dir)
    for fn in os.listdir(os.path.join(OUT,'per_case')) if os.path.isdir(os.path.join(OUT,'per_case')) else []:
        if fn.endswith('.json'): shutil.copy(os.path.join(OUT,'per_case',fn), os.path.join(dst,'per_case',fn))
    if os.path.exists(os.path.join(OUT,'synth_test_zoo.json')):
        shutil.copy(os.path.join(OUT,'synth_test_zoo.json'), os.path.join(dst,'synth_test_zoo.json'))
    cwd=os.getcwd(); os.chdir(repo)
    subprocess.run(['git','config','user.email','colab@gpu.run'])
    subprocess.run(['git','config','user.name','colab-gpu'])
    subprocess.run(['git','add','-f',f'results_hires_zoo/{FAMILY}/per_case',f'results_hires_zoo/{FAMILY}/synth_test_zoo.json'])
    if subprocess.run(['git','diff','--cached','--quiet']).returncode!=0:
        subprocess.run(['git','commit','-q','-m',msg])
        url=f'https://{GH_TOKEN}@github.com/grcarmenaty/phd_lanl.git'
        import time as _t; ok=False
        for _a in range(5):                       # retry the flaky push w/ backoff
            r=subprocess.run(['git','push','--force',url,f'HEAD:{GH_RESULTS_BRANCH}'],
                             capture_output=True,text=True)
            if r.returncode==0: ok=True; break
            _t.sleep(4*(2**_a))                    # 4,8,16,32,64s
        print('  autosave:', f'pushed -> {GH_RESULTS_BRANCH}' if ok
              else 'push failed after retries (results safe on Drive): '+r.stderr[-140:])
    os.chdir(cwd)

for (task, model, feature) in CELLS:
    try:
        Z.run_cell(task, model, feature, syn_h5=SYN, exp_h5=EXP, out_dir=OUT, dev=DEV,
                   syn_tasks=syn_tasks, exp_tasks=exp_tasks, H_ref_syn=H_ref_syn,
                   H_ref_exp=H_ref_exp, H_exp=H_exp, exp_names=exp_names,
                   make_split=make_split, subsample=SUBSAMPLE, batch=BATCH,
                   vision_size=VISION_SIZE, max_epochs=MAX_EPOCHS, patience=PATIENCE)
        git_autosave(f'colab autosave [{FAMILY}]: {task}/{model}/{feature}')
    except Exception as e:
        print('CELL FAILED', task, model, feature, '::', repr(e)[:200])
        if torch.cuda.is_available(): torch.cuda.empty_cache()
print('\nqueue done')
# Out:
# skip binary_cnn2d_shallow_cfdac_real_hires1601 (exists)
#   autosave: pushed -> colab-hires-cnn
# skip binary_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip binary_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip binary_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip binary_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip binary_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip binary_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip col_location_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip mass_location_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip severity_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip type_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip is_bolt_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip is_crack_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_real_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_imag_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_mag_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_phase_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_realimag_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_magphase_hires1601 (exists)
# skip is_mass_cnn2d_shallow_cfdac_all_hires1601 (exists)
# skip is_hole_cnn2d_shallow_cfdac_real_hires1601 (exists)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601: resume from epoch 10 (best=+0.5689, since=3)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601 ep11/80 val=+0.4336 best=+0.5689 since=4 (52s)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601 ep12/80 val=+0.5345 best=+0.5689 since=5 (68s)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601 ep13/80 val=+0.5069 best=+0.5689 since=6 (84s)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601 ep14/80 val=+0.5024 best=+0.5689 since=7 (100s)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601 ep15/80 val=+0.5481 best=+0.5689 since=8 (116s)
#     is_hole_cnn2d_shallow_cfdac_imag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_hole_cnn2d_shallow_cfdac_imag_hires1601: synth mF1=0.575  -> is_hole_cnn2d_shallow_cfdac_imag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep1/80 val=+0.1678 best=+0.1678 since=0 (17s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep2/80 val=+0.1678 best=+0.1678 since=1 (35s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep3/80 val=+0.4439 best=+0.4439 since=0 (53s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep4/80 val=+0.4439 best=+0.4439 since=1 (70s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep5/80 val=+0.1678 best=+0.4439 since=2 (87s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep6/80 val=+0.2361 best=+0.4439 since=3 (105s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep7/80 val=+0.1678 best=+0.4439 since=4 (122s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep8/80 val=+0.4136 best=+0.4439 since=5 (139s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep9/80 val=+0.1929 best=+0.4439 since=6 (157s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep10/80 val=+0.2905 best=+0.4439 since=7 (174s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep11/80 val=+0.4670 best=+0.4670 since=0 (192s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep12/80 val=+0.1906 best=+0.4670 since=1 (209s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep13/80 val=+0.1678 best=+0.4670 since=2 (226s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep14/80 val=+0.4439 best=+0.4670 since=3 (244s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep15/80 val=+0.4488 best=+0.4670 since=4 (261s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep16/80 val=+0.3039 best=+0.4670 since=5 (279s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep17/80 val=+0.3212 best=+0.4670 since=6 (296s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep18/80 val=+0.4429 best=+0.4670 since=7 (314s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep19/80 val=+0.5246 best=+0.5246 since=0 (331s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep20/80 val=+0.3574 best=+0.5246 since=1 (348s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep21/80 val=+0.4473 best=+0.5246 since=2 (366s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep22/80 val=+0.4786 best=+0.5246 since=3 (383s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep23/80 val=+0.4439 best=+0.5246 since=4 (401s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep24/80 val=+0.2568 best=+0.5246 since=5 (418s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep25/80 val=+0.4439 best=+0.5246 since=6 (435s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep26/80 val=+0.1906 best=+0.5246 since=7 (453s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601 ep27/80 val=+0.2507 best=+0.5246 since=8 (470s)
#     is_hole_cnn2d_shallow_cfdac_mag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_hole_cnn2d_shallow_cfdac_mag_hires1601: synth mF1=0.520  -> is_hole_cnn2d_shallow_cfdac_mag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep1/80 val=+0.1678 best=+0.1678 since=0 (17s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep2/80 val=+0.1678 best=+0.1678 since=1 (34s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep3/80 val=+0.1678 best=+0.1678 since=2 (50s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep4/80 val=+0.5435 best=+0.5435 since=0 (67s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep5/80 val=+0.4439 best=+0.5435 since=1 (84s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep6/80 val=+0.1884 best=+0.5435 since=2 (101s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep7/80 val=+0.3193 best=+0.5435 since=3 (117s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep8/80 val=+0.4333 best=+0.5435 since=4 (134s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep9/80 val=+0.5362 best=+0.5435 since=5 (151s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep10/80 val=+0.4439 best=+0.5435 since=6 (167s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep11/80 val=+0.5797 best=+0.5797 since=0 (184s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep12/80 val=+0.4693 best=+0.5797 since=1 (201s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep13/80 val=+0.5794 best=+0.5797 since=2 (218s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep14/80 val=+0.5792 best=+0.5797 since=3 (234s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep15/80 val=+0.5868 best=+0.5868 since=0 (251s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep16/80 val=+0.3264 best=+0.5868 since=1 (268s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep17/80 val=+0.4508 best=+0.5868 since=2 (285s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep18/80 val=+0.5928 best=+0.5928 since=0 (301s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep19/80 val=+0.4540 best=+0.5928 since=1 (318s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep20/80 val=+0.4429 best=+0.5928 since=2 (335s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep21/80 val=+0.5361 best=+0.5928 since=3 (351s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep22/80 val=+0.4439 best=+0.5928 since=4 (368s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep23/80 val=+0.4912 best=+0.5928 since=5 (385s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep24/80 val=+0.4625 best=+0.5928 since=6 (402s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep25/80 val=+0.6100 best=+0.6100 since=0 (418s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep26/80 val=+0.4665 best=+0.6100 since=1 (435s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep27/80 val=+0.4571 best=+0.6100 since=2 (452s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep28/80 val=+0.4439 best=+0.6100 since=3 (468s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep29/80 val=+0.6104 best=+0.6100 since=4 (485s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep30/80 val=+0.3950 best=+0.6100 since=5 (502s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep31/80 val=+0.5747 best=+0.6100 since=6 (519s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep32/80 val=+0.6212 best=+0.6212 since=0 (535s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep33/80 val=+0.4439 best=+0.6212 since=1 (552s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep34/80 val=+0.4439 best=+0.6212 since=2 (569s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep35/80 val=+0.5979 best=+0.6212 since=3 (586s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep36/80 val=+0.5333 best=+0.6212 since=4 (602s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep37/80 val=+0.6119 best=+0.6212 since=5 (619s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep38/80 val=+0.4797 best=+0.6212 since=6 (636s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep39/80 val=+0.6112 best=+0.6212 since=7 (652s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601 ep40/80 val=+0.5634 best=+0.6212 since=8 (669s)
#     is_hole_cnn2d_shallow_cfdac_phase_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_hole_cnn2d_shallow_cfdac_phase_hires1601: synth mF1=0.590  -> is_hole_cnn2d_shallow_cfdac_phase_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep1/80 val=+0.1678 best=+0.1678 since=0 (31s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep2/80 val=+0.1678 best=+0.1678 since=1 (49s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep3/80 val=+0.1884 best=+0.1884 since=0 (66s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep4/80 val=+0.1678 best=+0.1884 since=1 (84s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep5/80 val=+0.1678 best=+0.1884 since=2 (102s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep6/80 val=+0.1678 best=+0.1884 since=3 (119s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep7/80 val=+0.4439 best=+0.4439 since=0 (137s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep8/80 val=+0.2813 best=+0.4439 since=1 (155s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep9/80 val=+0.1678 best=+0.4439 since=2 (173s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep10/80 val=+0.1701 best=+0.4439 since=3 (191s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep11/80 val=+0.4439 best=+0.4439 since=4 (208s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep12/80 val=+0.1678 best=+0.4439 since=5 (226s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep13/80 val=+0.4439 best=+0.4439 since=6 (244s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep14/80 val=+0.4226 best=+0.4439 since=7 (262s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601 ep15/80 val=+0.1793 best=+0.4439 since=8 (279s)
#     is_hole_cnn2d_shallow_cfdac_realimag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_hole_cnn2d_shallow_cfdac_realimag_hires1601: synth mF1=0.444  -> is_hole_cnn2d_shallow_cfdac_realimag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
# CELL FAILED is_hole cnn2d_shallow cfdac_magphase :: OutOfMemoryError('CUDA out of memory. Tried to allocate 2.45 GiB. GPU 0 has a total capacity of 22.03 GiB of which 1.80 GiB is free. Including non-PyTorch memory, this process has 20.22 GiB memory in
# CELL FAILED is_hole cnn2d_shallow cfdac_all :: OutOfMemoryError('CUDA out of memory. Tried to allocate 4.89 GiB. GPU 0 has a total capacity of 22.03 GiB of which 3.83 GiB is free. Including non-PyTorch memory, this process has 18.20 GiB memory in
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep1/80 val=+0.4444 best=+0.4444 since=0 (16s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep2/80 val=+0.5291 best=+0.5291 since=0 (33s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep3/80 val=+0.4444 best=+0.5291 since=1 (49s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep4/80 val=+0.1667 best=+0.5291 since=2 (65s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep5/80 val=+0.1667 best=+0.5291 since=3 (81s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep6/80 val=+0.1667 best=+0.5291 since=4 (97s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep7/80 val=+0.1667 best=+0.5291 since=5 (113s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep8/80 val=+0.1667 best=+0.5291 since=6 (129s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep9/80 val=+0.1667 best=+0.5291 since=7 (145s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601 ep10/80 val=+0.2957 best=+0.5291 since=8 (161s)
#     is_pristine_cnn2d_shallow_cfdac_real_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_pristine_cnn2d_shallow_cfdac_real_hires1601: synth mF1=0.515  -> is_pristine_cnn2d_shallow_cfdac_real_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep1/80 val=+0.1667 best=+0.1667 since=0 (16s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep2/80 val=+0.1980 best=+0.1980 since=0 (32s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep3/80 val=+0.4921 best=+0.4921 since=0 (49s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep4/80 val=+0.4902 best=+0.4921 since=1 (65s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep5/80 val=+0.5098 best=+0.5098 since=0 (81s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep6/80 val=+0.5059 best=+0.5098 since=1 (97s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep7/80 val=+0.5344 best=+0.5344 since=0 (113s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep8/80 val=+0.4272 best=+0.5344 since=1 (129s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep9/80 val=+0.5347 best=+0.5344 since=2 (145s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep10/80 val=+0.5844 best=+0.5844 since=0 (161s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep11/80 val=+0.5410 best=+0.5844 since=1 (178s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep12/80 val=+0.6116 best=+0.6116 since=0 (194s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep13/80 val=+0.5242 best=+0.6116 since=1 (210s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep14/80 val=+0.5162 best=+0.6116 since=2 (226s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep15/80 val=+0.5187 best=+0.6116 since=3 (242s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep16/80 val=+0.4439 best=+0.6116 since=4 (258s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep17/80 val=+0.4758 best=+0.6116 since=5 (274s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep18/80 val=+0.6019 best=+0.6116 since=6 (290s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep19/80 val=+0.5303 best=+0.6116 since=7 (306s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601 ep20/80 val=+0.5962 best=+0.6116 since=8 (323s)
#     is_pristine_cnn2d_shallow_cfdac_imag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_pristine_cnn2d_shallow_cfdac_imag_hires1601: synth mF1=0.624  -> is_pristine_cnn2d_shallow_cfdac_imag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep1/80 val=+0.1667 best=+0.1667 since=0 (17s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep2/80 val=+0.1667 best=+0.1667 since=1 (35s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep3/80 val=+0.1781 best=+0.1781 since=0 (52s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep4/80 val=+0.1667 best=+0.1781 since=1 (70s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep5/80 val=+0.1667 best=+0.1781 since=2 (87s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep6/80 val=+0.1667 best=+0.1781 since=3 (105s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep7/80 val=+0.4444 best=+0.4444 since=0 (122s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep8/80 val=+0.4439 best=+0.4444 since=1 (139s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep9/80 val=+0.1667 best=+0.4444 since=2 (157s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep10/80 val=+0.2114 best=+0.4444 since=3 (174s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep11/80 val=+0.1690 best=+0.4444 since=4 (191s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep12/80 val=+0.4424 best=+0.4444 since=5 (209s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep13/80 val=+0.1667 best=+0.4444 since=6 (226s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep14/80 val=+0.5533 best=+0.5533 since=0 (244s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep15/80 val=+0.1872 best=+0.5533 since=1 (261s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep16/80 val=+0.4444 best=+0.5533 since=2 (278s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep17/80 val=+0.5483 best=+0.5533 since=3 (296s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep18/80 val=+0.5526 best=+0.5533 since=4 (313s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep19/80 val=+0.2452 best=+0.5533 since=5 (331s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep20/80 val=+0.2534 best=+0.5533 since=6 (348s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep21/80 val=+0.5701 best=+0.5701 since=0 (365s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep22/80 val=+0.4444 best=+0.5701 since=1 (383s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep23/80 val=+0.2575 best=+0.5701 since=2 (400s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep24/80 val=+0.2452 best=+0.5701 since=3 (417s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep25/80 val=+0.4444 best=+0.5701 since=4 (435s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep26/80 val=+0.1759 best=+0.5701 since=5 (452s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep27/80 val=+0.5348 best=+0.5701 since=6 (470s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep28/80 val=+0.5474 best=+0.5701 since=7 (487s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601 ep29/80 val=+0.4999 best=+0.5701 since=8 (504s)
#     is_pristine_cnn2d_shallow_cfdac_mag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_pristine_cnn2d_shallow_cfdac_mag_hires1601: synth mF1=0.592  -> is_pristine_cnn2d_shallow_cfdac_mag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep1/80 val=+0.4444 best=+0.4444 since=0 (17s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep2/80 val=+0.4738 best=+0.4738 since=0 (34s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep3/80 val=+0.5354 best=+0.5354 since=0 (50s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep4/80 val=+0.4434 best=+0.5354 since=1 (67s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep5/80 val=+0.5742 best=+0.5742 since=0 (84s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep6/80 val=+0.4439 best=+0.5742 since=1 (100s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep7/80 val=+0.4260 best=+0.5742 since=2 (117s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep8/80 val=+0.4444 best=+0.5742 since=3 (134s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep9/80 val=+0.4444 best=+0.5742 since=4 (150s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep10/80 val=+0.1667 best=+0.5742 since=5 (167s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep11/80 val=+0.6274 best=+0.6274 since=0 (184s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep12/80 val=+0.4444 best=+0.6274 since=1 (201s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep13/80 val=+0.4444 best=+0.6274 since=2 (217s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep14/80 val=+0.5932 best=+0.6274 since=3 (234s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep15/80 val=+0.4444 best=+0.6274 since=4 (251s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep16/80 val=+0.5262 best=+0.6274 since=5 (268s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep17/80 val=+0.6339 best=+0.6339 since=0 (284s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep18/80 val=+0.4444 best=+0.6339 since=1 (301s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep19/80 val=+0.6785 best=+0.6785 since=0 (318s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep20/80 val=+0.6954 best=+0.6954 since=0 (334s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep21/80 val=+0.2929 best=+0.6954 since=1 (351s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep22/80 val=+0.4444 best=+0.6954 since=2 (368s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep23/80 val=+0.7106 best=+0.7106 since=0 (385s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep24/80 val=+0.6845 best=+0.7106 since=1 (401s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep25/80 val=+0.6541 best=+0.7106 since=2 (418s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep26/80 val=+0.4444 best=+0.7106 since=3 (435s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep27/80 val=+0.1759 best=+0.7106 since=4 (451s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep28/80 val=+0.3798 best=+0.7106 since=5 (468s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep29/80 val=+0.2554 best=+0.7106 since=6 (485s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep30/80 val=+0.4099 best=+0.7106 since=7 (502s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601 ep31/80 val=+0.4444 best=+0.7106 since=8 (518s)
#     is_pristine_cnn2d_shallow_cfdac_phase_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_pristine_cnn2d_shallow_cfdac_phase_hires1601: synth mF1=0.717  -> is_pristine_cnn2d_shallow_cfdac_phase_hires1601.json
#   autosave: pushed -> colab-hires-cnn
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep1/80 val=+0.4444 best=+0.4444 since=0 (18s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep2/80 val=+0.5550 best=+0.5550 since=0 (36s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep3/80 val=+0.4393 best=+0.5550 since=1 (54s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep4/80 val=+0.4957 best=+0.5550 since=2 (71s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep5/80 val=+0.4444 best=+0.5550 since=3 (89s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep6/80 val=+0.6014 best=+0.6014 since=0 (107s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep7/80 val=+0.1667 best=+0.6014 since=1 (125s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep8/80 val=+0.1667 best=+0.6014 since=2 (142s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep9/80 val=+0.4540 best=+0.6014 since=3 (160s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep10/80 val=+0.4444 best=+0.6014 since=4 (178s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep11/80 val=+0.1667 best=+0.6014 since=5 (196s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep12/80 val=+0.2005 best=+0.6014 since=6 (213s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep13/80 val=+0.2251 best=+0.6014 since=7 (231s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601 ep14/80 val=+0.1882 best=+0.6014 since=8 (249s)
#     is_pristine_cnn2d_shallow_cfdac_realimag_hires1601: converged (no +0.001 in 8 epochs)
#   DONE is_pristine_cnn2d_shallow_cfdac_realimag_hires1601: synth mF1=0.604  -> is_pristine_cnn2d_shallow_cfdac_realimag_hires1601.json
#   autosave: pushed -> colab-hires-cnn
# CELL FAILED is_pristine cnn2d_shallow cfdac_magphase :: OutOfMemoryError('CUDA out of memory. Tried to allocate 2.45 GiB. GPU 0 has a total capacity of 22.03 GiB of which 1.80 GiB is free. Including non-PyTorch memory, this process has 20.22 GiB memory in
# CELL FAILED is_pristine cnn2d_shallow cfdac_all :: OutOfMemoryError('CUDA out of memory. Tried to allocate 4.89 GiB. GPU 0 has a total capacity of 22.03 GiB of which 3.83 GiB is free. Including non-PyTorch memory, this process has 18.20 GiB memory in
#
# queue done

# %% [markdown]
# ## 5 · Honest summary (balanced-acc / macro-F1 / collapse) + zip download

# %%
import json, numpy as np
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score, f1_score, accuracy_score
print(f"{'cell':<48}{'kind':>5}{'synth':>8}{'expMF1/R2':>11}{'expBal':>8}{'expAcc':>8}{'collapse':>9}")
print('-'*97)
for p in sorted((OUT/'per_case').glob('*_hires1601.json')):
    d=json.loads(p.read_text()); m=d['meta']; r=d['rows']
    yt=np.array([x['y_true'] for x in r]); yp=np.array([x['y_pred'] for x in r])
    name=f"{m['task']}/{m['model']}/{m['feature']}"
    if m['kind']=='cls':
        n=m['n_out']; bal=balanced_accuracy_score(yt,yp)
        mf1=f1_score(yt,yp,labels=list(range(n)),average='macro',zero_division=0); acc=accuracy_score(yt,yp)
        coll=(len(set(yp.tolist()))<=1) or (bal<=1/n+0.02)
        print(f"{name:<48}{'cls':>5}{(m.get('synth_test_macro_f1') or 0):>8.3f}{mf1:>11.3f}{bal:>8.3f}{acc:>8.3f}{str(coll):>9}")
    else:
        yt=yt.astype(float); yp=yp.astype(float); ss=np.sum((yt-yp)**2); st=np.sum((yt-yt.mean())**2)
        r2=1-ss/st if st>0 else 0; mae=np.mean(np.abs(yt-yp))
        print(f"{name:<48}{'reg':>5}{(m.get('synth_test_metric') or 0):>8.3f}{r2:>11.3f}{'-':>8}{'-':>8}{'MAE=%.3f'%mae:>9}")

# Zip for download (Drive already persists across sessions).
import shutil
z=str(OUT).rstrip('/').split('/')[-1]
shutil.make_archive('/content/'+z,'zip',str(OUT))
try:
    from google.colab import files; files.download('/content/'+z+'.zip')
except Exception as e: print('zip at /content/'+z+'.zip', e)
# Out:
# cell                                             kind   synth  expMF1/R2  expBal  expAcc collapse
# -------------------------------------------------------------------------------------------------
# binary/cnn2d_deep/cfdac_all                       cls   0.889      0.451   0.498   0.821     True
# binary/cnn2d_deep/cfdac_imag                      cls   0.773      0.439   0.452   0.726     True
# binary/cnn2d_deep/cfdac_mag                       cls   0.688      0.491   0.514   0.818     True
# binary/cnn2d_deep/cfdac_magphase                  cls   0.780      0.475   0.486   0.755     True
# binary/cnn2d_deep/cfdac_phase                     cls   0.796      0.438   0.468   0.770     True
# binary/cnn2d_deep/cfdac_real                      cls   0.729      0.427   0.422   0.641     True
# binary/cnn2d_deep/cfdac_realimag                  cls   0.837      0.448   0.476   0.775     True
# binary/cnn2d_shallow/cfdac_all                    cls   0.599      0.297   0.492   0.298     True
# binary/cnn2d_shallow/cfdac_imag                   cls   0.595      0.481   0.509   0.818     True
# binary/cnn2d_shallow/cfdac_mag                    cls   0.444      0.452   0.500   0.825     True
# binary/cnn2d_shallow/cfdac_magphase               cls   0.757      0.452   0.500   0.825     True
# binary/cnn2d_shallow/cfdac_phase                  cls   0.655      0.452   0.500   0.825     True
# binary/cnn2d_shallow/cfdac_real                   cls   0.548      0.490   0.490   0.709     True
# binary/cnn2d_shallow/cfdac_realimag               cls   0.589      0.452   0.499   0.823     True
# binary/cnn3d/cfdac_all                            cls   0.549      0.490   0.505   0.789     True
# binary/cnn3d/cfdac_imag                           cls   0.573      0.522   0.535   0.834    False
# binary/cnn3d/cfdac_mag                            cls   0.515      0.452   0.500   0.825     True
# binary/cnn3d/cfdac_magphase                       cls   0.610      0.452   0.500   0.825     True
# binary/cnn3d/cfdac_phase                          cls   0.771      0.452   0.500   0.825     True
# binary/cnn3d/cfdac_real                           cls   0.564      0.479   0.480   0.710     True
# binary/cnn3d/cfdac_realimag                       cls   0.566      0.542   0.542   0.739    False
# col_location/cnn2d_deep/cfdac_all                 cls   0.475      0.112   0.133   0.201     True
# col_location/cnn2d_deep/cfdac_imag                cls   0.320      0.136   0.154   0.217     True
# col_location/cnn2d_deep/cfdac_mag                 cls   0.457      0.163   0.316   0.213    False
# col_location/cnn2d_deep/cfdac_magphase            cls   0.506      0.003   0.002   0.004     True
# col_location/cnn2d_deep/cfdac_phase               cls   0.435      0.045   0.052   0.061     True
# col_location/cnn2d_deep/cfdac_real                cls   0.466      0.158   0.194   0.373    False
# col_location/cnn2d_deep/cfdac_realimag            cls   0.446      0.170   0.281   0.251    False
# col_location/cnn2d_shallow/cfdac_all              cls   0.447      0.114   0.262   0.237    False
# col_location/cnn2d_shallow/cfdac_imag             cls   0.324      0.047   0.167   0.165     True
# col_location/cnn2d_shallow/cfdac_mag              cls   0.218      0.038   0.176   0.084     True
# col_location/cnn2d_shallow/cfdac_magphase         cls   0.431      0.058   0.205   0.072    False
# col_location/cnn2d_shallow/cfdac_phase            cls   0.445      0.090   0.159   0.361     True
# col_location/cnn2d_shallow/cfdac_real             cls   0.152      0.028   0.026   0.059     True
# col_location/cnn2d_shallow/cfdac_realimag         cls   0.313      0.064   0.087   0.142     True
# col_location/cnn3d/cfdac_all                      cls   0.430      0.121   0.159   0.342     True
# col_location/cnn3d/cfdac_imag                     cls   0.184      0.050   0.167   0.100     True
# col_location/cnn3d/cfdac_mag                      cls   0.255      0.020   0.155   0.058     True
# col_location/cnn3d/cfdac_magphase                 cls   0.478      0.090   0.126   0.272     True
# col_location/cnn3d/cfdac_phase                    cls   0.502      0.141   0.220   0.197    False
# col_location/cnn3d/cfdac_real                     cls   0.346      0.106   0.222   0.189    False
# col_location/cnn3d/cfdac_realimag                 cls   0.423      0.045   0.031   0.068     True
# is_bolt/cnn2d_deep/cfdac_all                      cls   0.929      0.507   0.569   0.564    False
# is_bolt/cnn2d_deep/cfdac_imag                     cls   0.803      0.335   0.497   0.504     True
# is_bolt/cnn2d_deep/cfdac_mag                      cls   0.936      0.315   0.399   0.404     True
# is_bolt/cnn2d_deep/cfdac_magphase                 cls   0.940      0.451   0.507   0.502     True
# is_bolt/cnn2d_deep/cfdac_phase                    cls   0.933      0.330   0.500   0.493     True
# is_bolt/cnn2d_deep/cfdac_real                     cls   0.838      0.322   0.379   0.384     True
# is_bolt/cnn2d_deep/cfdac_realimag                 cls   0.798      0.466   0.557   0.563    False
# is_bolt/cnn2d_shallow/cfdac_all                   cls   0.932      0.389   0.473   0.467     True
# is_bolt/cnn2d_shallow/cfdac_imag                  cls   0.798      0.357   0.427   0.431     True
# is_bolt/cnn2d_shallow/cfdac_mag                   cls   0.594      0.315   0.399   0.404     True
# is_bolt/cnn2d_shallow/cfdac_magphase              cls   0.930      0.373   0.510   0.517     True
# is_bolt/cnn2d_shallow/cfdac_phase                 cls   0.808      0.330   0.500   0.493     True
# is_bolt/cnn2d_shallow/cfdac_real                  cls   0.798      0.416   0.524   0.530    False
# is_bolt/cnn2d_shallow/cfdac_realimag              cls   0.768      0.460   0.461   0.461     True
# is_bolt/cnn3d/cfdac_all                           cls   0.772      0.472   0.472   0.472     True
# is_bolt/cnn3d/cfdac_imag                          cls   0.768      0.628   0.629   0.629    False
# is_bolt/cnn3d/cfdac_mag                           cls   0.623      0.314   0.399   0.404     True
# is_bolt/cnn3d/cfdac_magphase                      cls   0.878      0.550   0.550   0.550    False
# is_bolt/cnn3d/cfdac_phase                         cls   0.887      0.471   0.476   0.478     True
# is_bolt/cnn3d/cfdac_real                          cls   0.778      0.438   0.454   0.457     True
# is_bolt/cnn3d/cfdac_realimag                      cls   0.783      0.489   0.495   0.497     True
# is_crack/cnn2d_deep/cfdac_all                     cls   0.642      0.464   0.493   0.866     True
# is_crack/cnn2d_deep/cfdac_imag                    cls   0.549      0.448   0.462   0.812     True
# is_crack/cnn2d_deep/cfdac_mag                     cls   0.533      0.468   0.500   0.879     True
# is_crack/cnn2d_deep/cfdac_magphase                cls   0.704      0.467   0.499   0.877     True
# is_crack/cnn2d_deep/cfdac_phase                   cls   0.515      0.457   0.457   0.767     True
# is_crack/cnn2d_deep/cfdac_real                    cls   0.504      0.487   0.487   0.783     True
# is_crack/cnn2d_deep/cfdac_realimag                cls   0.526      0.453   0.472   0.829     True
# is_crack/cnn2d_shallow/cfdac_all                  cls   0.547      0.292   0.278   0.370     True
# is_crack/cnn2d_shallow/cfdac_imag                 cls   0.541      0.456   0.477   0.838     True
# is_crack/cnn2d_shallow/cfdac_mag                  cls   0.481      0.468   0.500   0.879     True
# is_crack/cnn2d_shallow/cfdac_magphase             cls   0.548      0.423   0.416   0.732     True
# is_crack/cnn2d_shallow/cfdac_phase                cls   0.651      0.446   0.458   0.805     True
# is_crack/cnn2d_shallow/cfdac_real                 cls   0.530      0.453   0.471   0.827     True
# is_crack/cnn2d_shallow/cfdac_realimag             cls   0.523      0.465   0.494   0.868     True
# is_crack/cnn3d/cfdac_all                          cls   0.514      0.470   0.493   0.860     True
# is_crack/cnn3d/cfdac_imag                         cls   0.521      0.468   0.500   0.879     True
# is_crack/cnn3d/cfdac_mag                          cls   0.443      0.424   0.419   0.736     True
# is_crack/cnn3d/cfdac_magphase                     cls   0.560      0.464   0.492   0.865     True
# is_crack/cnn3d/cfdac_phase                        cls   0.610      0.468   0.500   0.879     True
# is_crack/cnn3d/cfdac_real                         cls   0.553      0.427   0.422   0.737     True
# is_crack/cnn3d/cfdac_realimag                     cls   0.552      0.464   0.468   0.795     True
# is_hole/cnn2d_deep/cfdac_imag                     cls   0.562      0.572   0.579   0.824    False
# is_hole/cnn2d_deep/cfdac_mag                      cls   0.444      0.472   0.500   0.894     True
# is_hole/cnn2d_deep/cfdac_phase                    cls   0.580      0.492   0.502   0.732     True
# is_hole/cnn2d_deep/cfdac_real                     cls   0.566      0.442   0.443   0.792     True
# is_hole/cnn2d_deep/cfdac_realimag                 cls   0.594      0.512   0.609   0.650    False
# is_hole/cnn2d_shallow/cfdac_imag                  cls   0.575      0.472   0.499   0.892     True
# is_hole/cnn2d_shallow/cfdac_mag                   cls   0.520      0.472   0.500   0.894     True
# is_hole/cnn2d_shallow/cfdac_phase                 cls   0.590      0.472   0.500   0.894     True
# is_hole/cnn2d_shallow/cfdac_real                  cls   0.508      0.483   0.483   0.773     True
# is_hole/cnn2d_shallow/cfdac_realimag              cls   0.444      0.483   0.482   0.777     True
# is_mass/cnn2d_deep/cfdac_all                      cls   0.973      0.422   0.400   0.711     True
# is_mass/cnn2d_deep/cfdac_imag                     cls   0.942      0.221   0.565   0.223    False
# is_mass/cnn2d_deep/cfdac_mag                      cls   0.531      0.229   0.577   0.230    False
# is_mass/cnn2d_deep/cfdac_magphase                 cls   0.970      0.083   0.500   0.090     True
# is_mass/cnn2d_deep/cfdac_phase                    cls   0.981      0.365   0.482   0.440     True
# is_mass/cnn2d_deep/cfdac_real                     cls   0.929      0.484   0.503   0.908     True
# is_mass/cnn2d_deep/cfdac_realimag                 cls   0.599      0.547   0.618   0.745    False
# is_mass/cnn2d_shallow/cfdac_all                   cls   0.916      0.476   0.500   0.909     True
# is_mass/cnn2d_shallow/cfdac_imag                  cls   0.637      0.083   0.500   0.090     True
# is_mass/cnn2d_shallow/cfdac_mag                   cls   0.559      0.090   0.503   0.096     True
# is_mass/cnn2d_shallow/cfdac_magphase              cls   0.960      0.378   0.334   0.604     True
# is_mass/cnn2d_shallow/cfdac_phase                 cls   0.933      0.474   0.495   0.901     True
# is_mass/cnn2d_shallow/cfdac_real                  cls   0.586      0.323   0.565   0.350    False
# is_mass/cnn2d_shallow/cfdac_realimag              cls   0.763      0.083   0.500   0.090     True
# is_mass/cnn3d/cfdac_all                           cls   0.895      0.083   0.500   0.090     True
# is_mass/cnn3d/cfdac_imag                          cls   0.585      0.399   0.620   0.456    False
# is_mass/cnn3d/cfdac_mag                           cls   0.561      0.231   0.578   0.233    False
# is_mass/cnn3d/cfdac_magphase                      cls   0.911      0.203   0.562   0.204    False
# is_mass/cnn3d/cfdac_phase                         cls   0.925      0.319   0.557   0.346    False
# is_mass/cnn3d/cfdac_real                          cls   0.619      0.254   0.589   0.259    False
# is_mass/cnn3d/cfdac_realimag                      cls   0.613      0.366   0.577   0.413    False
# is_pristine/cnn2d_shallow/cfdac_imag              cls   0.624      0.457   0.500   0.821     True
# is_pristine/cnn2d_shallow/cfdac_mag               cls   0.592      0.452   0.500   0.824     True
# is_pristine/cnn2d_shallow/cfdac_phase             cls   0.717      0.452   0.500   0.825     True
# is_pristine/cnn2d_shallow/cfdac_real              cls   0.515      0.438   0.443   0.698     True
# is_pristine/cnn2d_shallow/cfdac_realimag          cls   0.604      0.464   0.504   0.823     True
# mass_location/cnn2d_deep/cfdac_all                cls   0.993      0.102   0.250   0.256     True
# mass_location/cnn2d_deep/cfdac_imag               cls   0.990      0.072   0.250   0.168     True
# mass_location/cnn2d_deep/cfdac_mag                cls   0.953      0.102   0.250   0.256     True
# mass_location/cnn2d_deep/cfdac_magphase           cls   1.000      0.102   0.250   0.256     True
# mass_location/cnn2d_deep/cfdac_phase              cls   1.000      0.102   0.250   0.256     True
# mass_location/cnn2d_deep/cfdac_real               cls   0.987      0.145   0.250   0.408     True
# mass_location/cnn2d_deep/cfdac_realimag           cls   0.828      0.196   0.332   0.303    False
# mass_location/cnn2d_shallow/cfdac_all             cls   0.947      0.072   0.250   0.168     True
# mass_location/cnn2d_shallow/cfdac_imag            cls   0.931      0.102   0.250   0.256     True
# mass_location/cnn2d_shallow/cfdac_mag             cls   0.675      0.102   0.250   0.256     True
# mass_location/cnn2d_shallow/cfdac_magphase        cls   0.834      0.176   0.336   0.256    False
# mass_location/cnn2d_shallow/cfdac_phase           cls   0.951      0.308   0.358   0.517    False
# mass_location/cnn2d_shallow/cfdac_real            cls   0.732      0.147   0.245   0.185     True
# mass_location/cnn2d_shallow/cfdac_realimag        cls   0.960      0.102   0.250   0.256     True
# mass_location/cnn3d/cfdac_all                     cls   0.717      0.080   0.086   0.088     True
# mass_location/cnn3d/cfdac_imag                    cls   0.561      0.280   0.412   0.366    False
# mass_location/cnn3d/cfdac_mag                     cls   0.383      0.102   0.250   0.256     True
# mass_location/cnn3d/cfdac_magphase                cls   0.763      0.282   0.381   0.345    False
# mass_location/cnn3d/cfdac_phase                   cls   0.963      0.119   0.234   0.239     True
# mass_location/cnn3d/cfdac_real                    cls   0.683      0.193   0.186   0.155     True
# mass_location/cnn3d/cfdac_realimag                cls   0.721      0.235   0.322   0.282    False
# severity/cnn2d_deep/cfdac_all                     reg   0.462   -127.150       -       -MAE=3.376
# severity/cnn2d_deep/cfdac_imag                    reg   0.027     -3.310       -       -MAE=0.596
# severity/cnn2d_deep/cfdac_mag                     reg   0.039     -2.693       -       -MAE=0.501
# severity/cnn2d_deep/cfdac_magphase                reg   0.358  -3131.753       -       -MAE=17.782
# severity/cnn2d_deep/cfdac_phase                   reg   0.367  -1966.978       -       -MAE=13.956
# severity/cnn2d_deep/cfdac_real                    reg   0.575    -49.491       -       -MAE=1.822
# severity/cnn2d_deep/cfdac_realimag                reg   0.176     -2.798       -       -MAE=0.500
# severity/cnn2d_shallow/cfdac_all                  reg  -0.165     -1.148       -       -MAE=0.360
# severity/cnn2d_shallow/cfdac_imag                 reg   0.139   -160.171       -       -MAE=3.857
# severity/cnn2d_shallow/cfdac_mag                  reg   0.077     -0.804       -       -MAE=0.352
# severity/cnn2d_shallow/cfdac_magphase             reg   0.246    -31.260       -       -MAE=1.764
# severity/cnn2d_shallow/cfdac_phase                reg   0.203    -18.306       -       -MAE=1.333
# severity/cnn2d_shallow/cfdac_real                 reg   0.132     -1.362       -       -MAE=0.378
# severity/cnn2d_shallow/cfdac_realimag             reg   0.119    -13.154       -       -MAE=1.024
# severity/cnn3d/cfdac_all                          reg   0.183     -8.953       -       -MAE=0.882
# severity/cnn3d/cfdac_imag                         reg   0.100     -6.864       -       -MAE=0.818
# severity/cnn3d/cfdac_mag                          reg   0.040     -1.169       -       -MAE=0.407
# severity/cnn3d/cfdac_magphase                     reg   0.274    -62.275       -       -MAE=2.471
# severity/cnn3d/cfdac_phase                        reg   0.262    -31.512       -       -MAE=1.739
# severity/cnn3d/cfdac_real                         reg   0.128     -2.184       -       -MAE=0.502
# severity/cnn3d/cfdac_realimag                     reg   0.128     -4.474       -       -MAE=0.669
# type/cnn2d_deep/cfdac_all                         cls   0.853      0.128   0.247   0.264    False
# type/cnn2d_deep/cfdac_imag                        cls   0.768      0.162   0.261   0.367    False
# type/cnn2d_deep/cfdac_mag                         cls   0.659      0.085   0.178   0.142     True
# type/cnn2d_deep/cfdac_magphase                    cls   0.841      0.136   0.174   0.367     True
# type/cnn2d_deep/cfdac_phase                       cls   0.795      0.033   0.200   0.090     True
# type/cnn2d_deep/cfdac_real                        cls   0.743      0.135   0.200   0.506     True
# type/cnn2d_deep/cfdac_realimag                    cls   0.718      0.142   0.251   0.297    False
# type/cnn2d_shallow/cfdac_all                      cls   0.355      0.079   0.182   0.181     True
# type/cnn2d_shallow/cfdac_imag                     cls   0.437      0.135   0.200   0.507     True
# type/cnn2d_shallow/cfdac_mag                      cls   0.199      0.124   0.162   0.392     True
# type/cnn2d_shallow/cfdac_magphase                 cls   0.430      0.126   0.180   0.455     True
# type/cnn2d_shallow/cfdac_phase                    cls   0.591      0.135   0.200   0.507     True
# type/cnn2d_shallow/cfdac_real                     cls   0.420      0.138   0.202   0.508     True
# type/cnn2d_shallow/cfdac_realimag                 cls   0.433      0.119   0.162   0.410     True
# type/cnn3d/cfdac_all                              cls   0.445      0.127   0.174   0.319     True
# type/cnn3d/cfdac_imag                             cls   0.344      0.146   0.198   0.471     True
# type/cnn3d/cfdac_mag                              cls   0.334      0.134   0.198   0.503     True
# type/cnn3d/cfdac_magphase                         cls   0.470      0.129   0.175   0.427     True
# type/cnn3d/cfdac_phase                            cls   0.593      0.135   0.200   0.507     True
# type/cnn3d/cfdac_real                             cls   0.368      0.195   0.248   0.466    False
# type/cnn3d/cfdac_realimag                         cls   0.336      0.198   0.247   0.344    False

# %% [markdown]
# ## 6 · (Optional) push JSON results back to the repo

# %%
# Optional: force the full JSON snapshot to the results branch now (JSON only,
# no model weights). Same robust path as the per-cell autosave; safe to re-run.
import os, subprocess, shutil, glob, time as _t
tok=None
try:
    from google.colab import userdata; tok=userdata.get('GH_TOKEN')
except Exception: tok=os.environ.get('GH_TOKEN')
if not tok:
    print('No GH_TOKEN - download the zip from the cell above and hand it to the agent.')
else:
    repo='/content/PhD_LANL'; dst=os.path.join(repo,'results_hires_zoo',FAMILY)
    os.makedirs(os.path.join(dst,'per_case'), exist_ok=True)
    for fn in (os.listdir(os.path.join(OUT,'per_case')) if os.path.isdir(os.path.join(OUT,'per_case')) else []):
        if fn.endswith('.json'): shutil.copy(os.path.join(OUT,'per_case',fn), os.path.join(dst,'per_case',fn))
    for sj in glob.glob(os.path.join(OUT,'synth_test_*.json')):
        shutil.copy(sj, os.path.join(dst, os.path.basename(sj)))
    os.chdir(repo)
    subprocess.run(['git','config','user.email','colab@gpu.run']); subprocess.run(['git','config','user.name','colab-gpu'])
    subprocess.run(['git','add','-f',f'results_hires_zoo/{FAMILY}'])
    subprocess.run(['git','commit','-q','-m',f'hires {FAMILY} (GPU): manual JSON snapshot'])
    url=f'https://{tok}@github.com/grcarmenaty/phd_lanl.git'; ok=False
    for _a in range(5):
        r=subprocess.run(['git','push','--force',url,f'HEAD:{GH_RESULTS_BRANCH}'],capture_output=True,text=True)
        if r.returncode==0: ok=True; break
        _t.sleep(4*(2**_a))
    print(f'pushed -> {GH_RESULTS_BRANCH}' if ok else 'push failed after retries: '+r.stderr[-200:])
# Out:
# pushed -> colab-hires-cnn
